# %% [markdown]
# <a href="https://colab.research.google.com/github/hamshavarsha/The-Grand-Complete-Data-Science-Materials/blob/main/ADS_Phase3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Uploading and Displaying Dataset
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014 (1).csv')
print(df)
# Out:
#       Stn Code Sampling Date       State City/Town/Village/Area  \
# 0           38      01-02-14  Tamil Nadu                Chennai
# 1           38      01-07-14  Tamil Nadu                Chennai
# 2           38      21-01-14  Tamil Nadu                Chennai
# 3           38      23-01-14  Tamil Nadu                Chennai
# 4           38      28-01-14  Tamil Nadu                Chennai
# ...        ...           ...         ...                    ...
# 2874       773      12-03-14  Tamil Nadu                 Trichy
# 2875       773      12-10-14  Tamil Nadu                 Trichy
# 2876       773      17-12-14  Tamil Nadu                 Trichy
# 2877       773      24-12-14  Tamil Nadu                 Trichy
# 2878       773      31-12-14  Tamil Nadu                 Trichy
#
#                         Location of Monitoring Station  \
# 0     Kathivakkam, Municipal Kalyana Mandapam, Chennai
# 1     Kathivakkam, Municipal Kalyana Mandapam, Chennai
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014.csv')

# creating a list of column names
Column_name = pd.DataFrame(df.columns)
print('List of column names :',Column_name)
# Out:
# List of column names :                                  0
# 0                         Stn Code
# 1                    Sampling Date
# 2                            State
# 3           City/Town/Village/Area
# 4   Location of Monitoring Station
# 5                           Agency
# 6                 Type of Location
# 7                              SO2
# 8                              NO2
# 9                        RSPM/PM10
# 10                          PM 2.5

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014.csv')

#Displaying First 5 rows
print(df.head())
# Out:
#    Stn Code Sampling Date       State City/Town/Village/Area  \
# 0        38      01-02-14  Tamil Nadu                Chennai
# 1        38      01-07-14  Tamil Nadu                Chennai
# 2        38      21-01-14  Tamil Nadu                Chennai
# 3        38      23-01-14  Tamil Nadu                Chennai
# 4        38      28-01-14  Tamil Nadu                Chennai
#
#                      Location of Monitoring Station  \
# 0  Kathivakkam, Municipal Kalyana Mandapam, Chennai
# 1  Kathivakkam, Municipal Kalyana Mandapam, Chennai
# 2  Kathivakkam, Municipal Kalyana Mandapam, Chennai
# 3  Kathivakkam, Municipal Kalyana Mandapam, Chennai
# 4  Kathivakkam, Municipal Kalyana Mandapam, Chennai
#
#                                     Agency Type of Location   SO2   NO2  \
# 0  Tamilnadu State Pollution Control Board  Industrial Area  11.0  17.0
# 1  Tamilnadu State Pollution Control Board  Industrial Area  13.0  17.0
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014.csv')

#Displaying Last 5 rows
print(df.tail())
# Out:
#       Stn Code Sampling Date       State City/Town/Village/Area  \
# 2874       773      12-03-14  Tamil Nadu                 Trichy
# 2875       773      12-10-14  Tamil Nadu                 Trichy
# 2876       773      17-12-14  Tamil Nadu                 Trichy
# 2877       773      24-12-14  Tamil Nadu                 Trichy
# 2878       773      31-12-14  Tamil Nadu                 Trichy
#
#      Location of Monitoring Station                                   Agency  \
# 2874      Central Bus Stand, Trichy  Tamilnadu State Pollution Control Board
# 2875      Central Bus Stand, Trichy  Tamilnadu State Pollution Control Board
# 2876      Central Bus Stand, Trichy  Tamilnadu State Pollution Control Board
# 2877      Central Bus Stand, Trichy  Tamilnadu State Pollution Control Board
# 2878      Central Bus Stand, Trichy  Tamilnadu State Pollution Control Board
#
#                         Type of Location   SO2   NO2  RSPM/PM10  PM 2.5
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014.csv')

#Data Manipulation
print("shape of dataframe", df.shape)
print("number of rows : ", df.shape[0])
print("number of columns : ", df.shape[1])
print("DataFrame Size : ", df.size)
print('Info: ', df.info())
print('Correlation: ', df.corr())
# Out:
# shape of dataframe (2879, 11)
# number of rows :  2879
# number of columns :  11
# DataFrame Size :  31669

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014 (1).csv')

#Dropping Empty Cells
Emp_drop = df.dropna(how= "all", axis=1)
print(df)
# Out:
#       Stn Code Sampling Date       State City/Town/Village/Area  \
# 0           38      01-02-14  Tamil Nadu                Chennai
# 1           38      01-07-14  Tamil Nadu                Chennai
# 2           38      21-01-14  Tamil Nadu                Chennai
# 3           38      23-01-14  Tamil Nadu                Chennai
# 4           38      28-01-14  Tamil Nadu                Chennai
# ...        ...           ...         ...                    ...
# 2874       773      12-03-14  Tamil Nadu                 Trichy
# 2875       773      12-10-14  Tamil Nadu                 Trichy
# 2876       773      17-12-14  Tamil Nadu                 Trichy
# 2877       773      24-12-14  Tamil Nadu                 Trichy
# 2878       773      31-12-14  Tamil Nadu                 Trichy
#
#                         Location of Monitoring Station  \
# 0     Kathivakkam, Municipal Kalyana Mandapam, Chennai
# 1     Kathivakkam, Municipal Kalyana Mandapam, Chennai
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014 (1).csv')

#Dropping Empty Cells
df = df.drop(columns=df.columns[1:3], inplace=True)
print(df)
# Out:
# None

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014.csv')

#Dropping Empty Cells
df = df.dropna()
print(df)
# Out:
# Empty DataFrame
# Columns: [Stn Code, Sampling Date, State, City/Town/Village/Area, Location of Monitoring Station, Agency, Type of Location, SO2, NO2, RSPM/PM10, PM 2.5]
# Index: []

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014 (1).csv')

#Dropping Empty Cells
df=df. dropna(subset = ['Stn Code'])
df=df. dropna(subset = ['RSPM/PM10'])
print(df)
# Out:
#       Stn Code Sampling Date       State City/Town/Village/Area  \
# 0           38      01-02-14  Tamil Nadu                Chennai
# 1           38      01-07-14  Tamil Nadu                Chennai
# 2           38      21-01-14  Tamil Nadu                Chennai
# 3           38      23-01-14  Tamil Nadu                Chennai
# 4           38      28-01-14  Tamil Nadu                Chennai
# ...        ...           ...         ...                    ...
# 2874       773      12-03-14  Tamil Nadu                 Trichy
# 2875       773      12-10-14  Tamil Nadu                 Trichy
# 2876       773      17-12-14  Tamil Nadu                 Trichy
# 2877       773      24-12-14  Tamil Nadu                 Trichy
# 2878       773      31-12-14  Tamil Nadu                 Trichy
#
#                         Location of Monitoring Station  \
# 0     Kathivakkam, Municipal Kalyana Mandapam, Chennai
# 1     Kathivakkam, Municipal Kalyana Mandapam, Chennai
# ...

# %%
print('Correlation: ', df.corr())
# Out:
# Correlation:             Stn Code       SO2       NO2  RSPM/PM10
# Stn Code   1.000000  0.262942 -0.043095   0.336190
# SO2        0.262942  1.000000  0.078491   0.445152
# NO2       -0.043095  0.078491  1.000000   0.068277
# RSPM/PM10  0.336190  0.445152  0.068277   1.000000
# <ipython-input-16-98476de9b40e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Correlation: ', df.corr())

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014 (1).csv')

#Create Duplicate Columns
pd.get_dummies(df)
# Out:
#       Stn Code   SO2   NO2  RSPM/PM10  PM 2.5  Sampling Date_01-02-14  \
# 0           38  11.0  17.0       55.0     NaN                       1
# 1           38  13.0  17.0       45.0     NaN                       0
# 2           38  12.0  18.0       50.0     NaN                       0
# 3           38  15.0  16.0       46.0     NaN                       0
# 4           38  13.0  14.0       42.0     NaN                       0
# ...        ...   ...   ...        ...     ...                     ...
# 2874       773  15.0  18.0      102.0     NaN                       0
# 2875       773  12.0  14.0       91.0     NaN                       0
# 2876       773  19.0  22.0      100.0     NaN                       0
# 2877       773  15.0  17.0       95.0     NaN                       0
# 2878       773  14.0  16.0       94.0     NaN                       0
#
#       Sampling Date_01-03-14  Sampling Date_01-04-14  Sampling Date_01-06-14  \
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014.csv')

#Take care of missing data(just for first 5 rows)
df = df.head(5)
df.notnull()
# Out:
#    Stn Code  Sampling Date  State  City/Town/Village/Area  \
# 0      True           True   True                    True
# 1      True           True   True                    True
# 2      True           True   True                    True
# 3      True           True   True                    True
# 4      True           True   True                    True
#
#    Location of Monitoring Station  Agency  Type of Location   SO2   NO2  \
# 0                            True    True              True  True  True
# 1                            True    True              True  True  True
# 2                            True    True              True  True  True
# 3                            True    True              True  True  True
# 4                            True    True              True  True  True
#
#    RSPM/PM10  PM 2.5
# 0       True   False
# 1       True   False
# 2       True   False
# 3       True   False
# 4       True   False

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014.csv')

#Change data to Numpy
df.to_numpy()
# Out:
# array([[38, '01-02-14', 'Tamil Nadu', ..., 17.0, 55.0, nan],
#        [38, '01-07-14', 'Tamil Nadu', ..., 17.0, 45.0, nan],
#        [38, '21-01-14', 'Tamil Nadu', ..., 18.0, 50.0, nan],
#        ...,
#        [773, '17-12-14', 'Tamil Nadu', ..., 22.0, 100.0, nan],
#        [773, '24-12-14', 'Tamil Nadu', ..., 17.0, 95.0, nan],
#        [773, '31-12-14', 'Tamil Nadu', ..., 16.0, 94.0, nan]],
#       dtype=object)

# %%
import pandas as pd
df = pd.read_csv('/content/cpcb_dly_aq_tamil_nadu-2014.csv')

# Shuffle dataframe
df = df.sample(frac=1)
print(df)
# Out:
#       Stn Code Sampling Date       State City/Town/Village/Area  \
# 2288       239      22-09-14  Tamil Nadu            Thoothukudi
# 1959       762      29-09-14  Tamil Nadu                 Mettur
# 2472       240      13-08-14  Tamil Nadu            Thoothukudi
# 1823       308      20-05-14  Tamil Nadu                Madurai
# 1438       761      25-06-14  Tamil Nadu              Cuddalore
# 797        159      08-08-14  Tamil Nadu                Chennai
# 1098       375      17-12-14  Tamil Nadu             Coimbatore
# 1351       759      08-06-14  Tamil Nadu              Cuddalore
# 1299       759      29-01-14  Tamil Nadu              Cuddalore
# 251         72      27-08-14  Tamil Nadu                Chennai
# 952        160      30-05-14  Tamil Nadu                Chennai
# 152         71      21-08-14  Tamil Nadu                Chennai
# 2430       240      19-03-14  Tamil Nadu            Thoothukudi
# 493        765      11-12-14  Tamil Nadu                Chennai
# ...
